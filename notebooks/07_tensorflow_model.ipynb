# %%
import sys
from pathlib import Path

from src.DL_modelling import train_tensorflow_mlp

# %%
food_results = train_tensorflow_mlp(target="food")
# Out:
# WARNING:tensorflow:From C:\Users\dell 5590 i7\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
#
# Target distribution:
# target
# High        1706
# Very Low     524
# Low          349
# Marginal     307
# Name: count, dtype: int64
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,688 │
# ...

# %%
food_results["history"]
# Out:
#     epoch      loss  val_loss  accuracy  val_accuracy  precision_weighted  \
# 0       1  1.226370  1.041165  0.506931      0.658199            0.516650
# 1       2  1.119855  0.966119  0.618317      0.655889            0.615951
# 2       3  1.081876  0.943686  0.621782      0.662818            0.600751
# 3       4  1.054850  0.933151  0.628713      0.651270            0.626167
# 4       5  1.056572  0.928524  0.625743      0.648961            0.627165
# 5       6  1.027756  0.925418  0.639604      0.651270            0.635290
# 6       7  1.024337  0.926665  0.644059      0.648961            0.639829
# 7       8  1.007977  0.908561  0.645545      0.653580            0.645116
# 8       9  1.003904  0.922609  0.651485      0.651270            0.639341
# 9      10  1.007337  0.918579  0.653465      0.655889            0.642704
# 10     11  0.996431  0.913894  0.650990      0.658199            0.644730
# 11     12  0.987375  0.916936  0.649505      0.653580            0.655534
# ...

# %%
food_results["metrics"]
# Out:
#                metric     value
# 0            accuracy  0.646651
# 1  precision_weighted  0.576383
# 2     recall_weighted  0.646651
# 3         f1_weighted  0.601216
# 4            f1_macro  0.389259
# 5           test_loss  0.950020
# 6       test_accuracy  0.646651

# %%
food_results["classification_report"]
# Out:
#               precision    recall  f1-score     support
# High           0.755102  0.867188  0.807273  256.000000
# Marginal       0.111111  0.043478  0.062500   46.000000
# Low            0.222222  0.075472  0.112676   53.000000
# Very Low       0.504854  0.666667  0.574586   78.000000
# accuracy       0.646651  0.646651  0.646651    0.646651
# macro avg      0.398322  0.413201  0.389259  433.000000
# weighted avg   0.576383  0.646651  0.601216  433.000000

# %%
food_results["predictions"].head(20)
# Out:
#     actual  predicted actual_label predicted_label  correct  probability_high  \
# 0        0          3         High        Very Low    False          0.281386
# 1        3          0     Very Low            High    False          0.473290
# 2        0          0         High            High     True          0.812316
# 3        2          0          Low            High    False          0.313670
# 4        0          0         High            High     True          0.869502
# 5        0          0         High            High     True          0.356524
# 6        1          2     Marginal             Low    False          0.271434
# 7        0          0         High            High     True          0.333231
# 8        1          0     Marginal            High    False          0.567306
# 9        3          0     Very Low            High    False          0.425698
# 10       0          0         High            High     True          0.683249
# ...

# %%
food_results["confusion_matrix"]
# Out:
# array([[222,  12,   5,  17],
#        [ 27,   2,   3,  14],
#        [ 25,   4,   4,  20],
#        [ 20,   0,   6,  52]], dtype=int64)

# %%
food_results["plot_paths"]
# Out:
# {'loss_plot': WindowsPath('C:/Users/dell 5590 i7/Documents/GITHUB/vanguard-group/outputs/training/food/tensorflow_loss_history.png'),
#  'accuracy_plot': WindowsPath('C:/Users/dell 5590 i7/Documents/GITHUB/vanguard-group/outputs/training/food/tensorflow_accuracy_history.png'),
#  'metrics_plot': WindowsPath('C:/Users/dell 5590 i7/Documents/GITHUB/vanguard-group/outputs/training/food/tensorflow_validation_metrics_history.png'),
#  'confusion_matrix_plot': WindowsPath('C:/Users/dell 5590 i7/Documents/GITHUB/vanguard-group/outputs/training/food/tensorflow_confusion_matrix.png')}

# %%
fuel_results =train_tensorflow_mlp(target="fuel")
# Out:
# Target distribution:
# target
# High        1527
# Low          585
# Marginal     546
# Very Low     228
# Name: count, dtype: int64
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ...

# %%
fuel_results["history"]
# Out:
#     epoch      loss  val_loss  accuracy  val_accuracy  precision_weighted  \
# 0       1  1.264718  1.159404  0.444554      0.540416            0.464603
# 1       2  1.164331  1.109344  0.537129      0.542725            0.497826
# 2       3  1.136287  1.105147  0.536634      0.545035            0.515025
# 3       4  1.128840  1.096638  0.539109      0.538106            0.525859
# 4       5  1.110070  1.098014  0.548020      0.547344            0.530970
# 5       6  1.094120  1.092640  0.544059      0.538106            0.540031
# 6       7  1.087697  1.092361  0.562871      0.540416            0.554098
# 7       8  1.088416  1.084849  0.552475      0.540416            0.556453
# 8       9  1.077455  1.088529  0.557426      0.535797            0.557800
# 9      10  1.069208  1.078773  0.548515      0.540416            0.554807
# 10     11  1.065700  1.082399  0.557921      0.549654            0.570686
# 11     12  1.052263  1.081845  0.555941      0.538106            0.579792
# ...

# %%
fuel_results["metrics"]
# Out:
#                metric     value
# 0            accuracy  0.547344
# 1  precision_weighted  0.510061
# 2     recall_weighted  0.547344
# 3         f1_weighted  0.516128
# 4            f1_macro  0.386988
# 5           test_loss  1.074086
# 6       test_accuracy  0.547344

# %%
fuel_results["classification_report"]
# Out:
#               precision    recall  f1-score     support
# High           0.678967  0.803493  0.736000  229.000000
# Marginal       0.296296  0.097561  0.146789   82.000000
# Low            0.365591  0.386364  0.375691   88.000000
# Very Low       0.261905  0.323529  0.289474   34.000000
# accuracy       0.547344  0.547344  0.547344    0.547344
# macro avg      0.400690  0.402737  0.386988  433.000000
# weighted avg   0.510061  0.547344  0.516128  433.000000

# %%
fuel_results["predictions"].head(20)
# Out:
#     actual  predicted actual_label predicted_label  correct  probability_high  \
# 0        2          0          Low            High    False          0.606529
# 1        2          2          Low             Low     True          0.121801
# 2        0          0         High            High     True          0.566005
# 3        0          1         High        Marginal    False          0.238315
# 4        0          0         High            High     True          0.758549
# 5        1          1     Marginal        Marginal     True          0.239274
# 6        0          2         High             Low    False          0.187048
# 7        0          0         High            High     True          0.746643
# 8        2          2          Low             Low     True          0.153019
# 9        0          0         High            High     True          0.405561
# 10       3          3     Very Low        Very Low     True          0.063682
# ...

# %%
fuel_results["confusion_matrix"]
# Out:
# array([[184,  11,  25,   9],
#        [ 41,   8,  22,  11],
#        [ 37,   6,  34,  11],
#        [  9,   2,  12,  11]], dtype=int64)

# %%
fuel_results["plot_paths"]
# Out:
# {'loss_plot': WindowsPath('C:/Users/dell 5590 i7/Documents/GITHUB/vanguard-group/outputs/training/fuel/tensorflow_loss_history.png'),
#  'accuracy_plot': WindowsPath('C:/Users/dell 5590 i7/Documents/GITHUB/vanguard-group/outputs/training/fuel/tensorflow_accuracy_history.png'),
#  'metrics_plot': WindowsPath('C:/Users/dell 5590 i7/Documents/GITHUB/vanguard-group/outputs/training/fuel/tensorflow_validation_metrics_history.png'),
#  'confusion_matrix_plot': WindowsPath('C:/Users/dell 5590 i7/Documents/GITHUB/vanguard-group/outputs/training/fuel/tensorflow_confusion_matrix.png')}
